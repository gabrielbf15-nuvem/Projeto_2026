# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielbf15-nuvem/Projeto_2026/blob/main/LINGUAGEM_DE_PROGRAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
#1. Nosso primeiro programa
print("hello word")
# Out:
# hello word

# %%
#2.Criando variáveis de tipos diferentes
x = 10
nome = "Gabriel"
nota = 8.75
fez_incricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_incricao)
# Out:
# 10
# Gabriel
# 8.75
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_incricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("Digite seu nome:")
# Out:
# Digite seu nome:Gabriel

# %%
print(f"Olá {nome}, bem vindo a disciplina de programação")
# Out:
# Olá Gabriel, bem vindo a disciplina de programação

# %%
Nota_1 = int(input("DIGITE A NOTA: "))
Nota_2 = int(input("DIGITE A NOTA: "))
Nota_3 = int(input("DIGITE A NOTA: "))
Nota_4 = int(input("DIGITE A NOTA: "))
# Out:
# DIGITE A NOTA: 5
# DIGITE A NOTA: 6
# DIGITE A NOTA: 7
# DIGITE A NOTA: 8

# %%
media = (Nota_1+Nota_2+Nota_3+Nota_4)/4

# %%
print(media)
# Out:
# 6.5

# %%
if media >= 6:
    situacao = ("APROVADO")
else:
    situacao = ("REPROVADO")

# %%
print(situacao)
# Out:
# APROVADO

# %% [markdown]
# #U1_A2

# %%
print(10>5)
# Out:
# True

# %%
print(5>10)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
print(7!=7)
# Out:
# False

# %%
#guardando informações
idade = 18
e_maior_de_idade = idade >= 18
print (e_maior_de_idade)
# Out:
# True

# %%
print (True or False)
# Out:
# True

# %%
idade = int(input("Digite sua idade: "))
if idade < 18:
  print("Menor de idade")
elif idade>= 18 and idade <65:
  print("Adulto")
else:
  print("Idoso")
# Out:
# Digite sua idade: 11
# Menor de idade

# %%
idade = int(input("Digite sua idade: "))
if idade < 12:
  print("recomendamos filme infantil 1")
elif idade>= 12 and idade <18:
  print("recomendamos filme infantil 2")
else:
  print("recomendamos filme infantil 3")

quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("Ingressos disponiveis. Divirta-se no cinema.")
else:
  print("Desculpe, todos os ingressos foram vendidos.")
# Out:
# Digite sua idade: 12
# recomendamos filme infantil 2
# Ingressos disponiveis. Divirta-se no cinema.

# %%
idade = int(input("Digite sua idade: "))
if idade < 12:
  print("recomendamos filme infantil 1")
elif idade>= 12 and idade <18:
  print("recomendamos filme infantil 2")
else:
  print("recomendamos filme infantil 3")

quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("Ingressos disponiveis. Divirta-se no cinema.")
else:
  print("Desculpe, todos os ingressos foram vendidos.")
# Out:
# Digite sua idade: 13
# recomendamos filme infantil 2
# Ingressos disponiveis. Divirta-se no cinema.

# %%
idade = int(input("Digite sua idade: "))
if idade < 12:
  print("recomendamos filme infantil 1")
elif idade>= 12 and idade <18:
  print("recomendamos filme infantil 2")
else:
  print("recomendamos filme infantil 3")

quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("Ingressos disponiveis. Divirta-se no cinema.")
else:
  print("Desculpe, todos os ingressos foram vendidos.")
# Out:
# Digite sua idade: 14
# recomendamos filme infantil 2
# Ingressos disponiveis. Divirta-se no cinema.

# %% [markdown]
# #U1_A3

# %%
numeros = [1,2,3,4,5,6,7]
for numeros in numeros:
  print("%f Camisetas: {numeros}")
# Out:
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}
# %f Camisetas: {numeros}

# %%
print(type(numeros))
# Out:
# <class 'int'>

# %%
numero = int(input("Digite um número (ou 0 para sair): "))
while numero !=0:
 if numero % 2  == 0:
  print("O número é par. ")
else:
  print("O número é ímpar. ")
numero = int(input("Digite um número (ou 0 para sair): "))

# %%
for x in range(1,15,3):
  print(x)
# Out:
# 1
# 4
# 7
# 10
# 13

# %%
filmes = ["filme 1","filme 2","filme 3","filme 4","filme 5"]
print("Bem vindo a classificação do filme")
print("você tem cinco filmes para classificar")
print("Digite '0' a qualquer momento para parar.\n")

for filme in filmes:
  classificacao = input(f"Como você classifica '{filme}') de 1 a 5 (ou 0 para parar): ")

  if classificacao == '0':
    print("que pena")
    break

classificacao = int(classificacao)
if classificacao <1 or classificacao >5:
  print("Nota invalida")
else:
  print(f"Você classificou '{filme}' com a '{classificacao}' estrelas.\n")
  print("obrigado")
# Out:
# Bem vindo a classificação do filme
# você tem cinco filmes para classificar
# Digite '0' a qualquer momento para parar.
#
# Como você classifica 'filme 1') de 1 a 5 (ou 0 para parar): 1
# Como você classifica 'filme 2') de 1 a 5 (ou 0 para parar): 2
# Como você classifica 'filme 3') de 1 a 5 (ou 0 para parar): 3
# Como você classifica 'filme 4') de 1 a 5 (ou 0 para parar): 4
# Como você classifica 'filme 5') de 1 a 5 (ou 0 para parar): 5
# Você classificou 'filme 5' com a '5' estrelas.
#
# obrigado

# %% [markdown]
# #U1_A4

# %%
numero = [1,2,3,4,5]

comprimento = len(numero)

# %%
comprimento
# Out:
# 5

# %%
range(5)
# Out:
# range(0, 5)

# %%
def soma (a,b):
  resultado = a + b
  return resultado

# %%
resultado_soma = soma(5,6)

# %%
print(resultado_soma)
# Out:
# 11

# %%
def e_par(numero):
  if numero % 2 == 0:
    return True
  else:
    return False

# %%
numero = 156165165161556165
teste = e_par(numero)

# %%
print(teste)
# Out:
# False

# %%
media = 8.156166156165156165156
arredonadar_media = lambda media: round(media,2)

# %%
media_arredondada = arredonadar_media(media)
print(media_arredondada)
# Out:
# 8.16

# %%
# Out:
# 8.156166156165156
